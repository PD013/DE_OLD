# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
df = pd.read_csv('green_tripdata_2019-09.csv', nrows=100)
df
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1          2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2          2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3          2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4          2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-09-01 00:40:55   2019-09-01 00:48:35                  N
# 96         2  2019-09-01 00:13:52   2019-09-01 00:21:47                  N
# 97         2  2019-09-01 00:37:24   2019-09-01 01:02:31                  N
# 98         2  2019-09-01 00:22:15   2019-09-01 00:29:52                  N
# 99         2  2019-09-01 00:11:53   2019-09-01 00:30:31                  N
#
# ...

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, name='green_taxi_data', con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('green_tripdata_2019-09.csv', iterator=True, chunksize=10000)

# %%
df = next(df_iter)

# %%
df
# Out:
#       VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0            2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1            2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2            2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3            2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4            2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# ...        ...                  ...                   ...                ...
# 9995         2  2019-09-01 21:12:50   2019-09-01 21:21:44                  N
# 9996         2  2019-09-01 21:34:11   2019-09-01 21:48:58                  N
# 9997         2  2019-09-01 21:59:57   2019-09-01 22:03:55                  N
# 9998         2  2019-09-01 21:12:36   2019-09-01 21:24:06                  N
# 9999         2  2019-09-01 21:13:41   2019-09-01 21:38:04                  N
#
# ...

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head(n=1)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            65           189                5            2.0
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0         10.5    0.5      0.5        2.36           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    0.3         14.16             1          1
#
#    congestion_surcharge
# 0                   0.0

# %%
df.head(n=0).to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: total: 469 ms
# Wall time: 2.53 s
# 1000

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))

# %%
df_iter = pd.read_csv('taxi+_zone_lookup.csv', iterator=True, chunksize=1)
df = next(df_iter)

# %%
try:
    while True:
        t_start = time()

        df = next(df_iter)

        if df.empty:
            break  # Break the loop if there are no more chunks to read

        df.to_sql(name='taxi_zone_data', con=engine, if_exists='append', index=False)

        t_end = time()

        print('Inserted another chunk, took %.3f seconds' % (t_end - t_start))

except StopIteration:
    pass
# Out:
# Inserted another chunk, took 0.099 seconds
# Inserted another chunk, took 0.034 seconds
# Inserted another chunk, took 0.028 seconds
# Inserted another chunk, took 0.018 seconds
# Inserted another chunk, took 0.026 seconds
# Inserted another chunk, took 0.022 seconds
# Inserted another chunk, took 0.019 seconds
# Inserted another chunk, took 0.024 seconds
# Inserted another chunk, took 0.027 seconds
# Inserted another chunk, took 0.028 seconds
# Inserted another chunk, took 0.026 seconds
# Inserted another chunk, took 0.025 seconds
# Inserted another chunk, took 0.027 seconds
# Inserted another chunk, took 0.026 seconds
# Inserted another chunk, took 0.020 seconds
# Inserted another chunk, took 0.040 seconds
# Inserted another chunk, took 0.030 seconds
# Inserted another chunk, took 0.025 seconds
# Inserted another chunk, took 0.028 seconds
# Inserted another chunk, took 0.019 seconds
# Inserted another chunk, took 0.026 seconds
# Inserted another chunk, took 0.024 seconds
# ...
